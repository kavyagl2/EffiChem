# %%
import os
import numpy as np
import pandas as pd

results_dir = "/home/raghvendra2/Molformer_Finetuning/classification_model_clintox/Results"

metric_files = sorted([f for f in os.listdir(results_dir) if f.startswith("metrics_") and f.endswith(".npy")])

for file_name in metric_files:
    file_path = os.path.join(results_dir, file_name)
    
    try:
        metrics_dict = np.load(file_path, allow_pickle=True).item()
        metrics_df = pd.DataFrame(metrics_dict).T
        
        print(f"\n===== Metrics from: {file_name} =====")
        print(metrics_df.to_string())
        
    except Exception as e:
        print(f"Error reading {file_name}: {e}")
# Out:
# ===== Metrics from: metrics_ChemBERTa_10M_MLM_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.958  0.9805     0.9779  0.7692     0.958    0.8387  0.7174
# LightGBM     0.972  0.9917     0.9851  0.8462     0.972    0.9015  0.8195
# CatBoost     0.986  0.9888     0.9924  0.9231     0.986    0.9545  0.9129
#
# ===== Metrics from: metrics_ChemBERTa_10M_MLM_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.986  0.9916     0.8889  0.9926     0.986    0.9338  0.8754
# LightGBM     0.979  0.9947     0.8500  0.9890     0.979    0.9062  0.8274
# CatBoost     0.972  0.9958     0.8182  0.9853     0.972    0.8814  0.7859
#
# ===== Metrics from: metrics_ChemBERTa_10M_MTR_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.965  0.9846     0.9815  0.8077     0.965    0.8715  0.7698
# LightGBM     0.958  0.9633     0.8939  0.8385     0.958    0.8635  0.7303
# CatBoost     0.979  0.9917     0.9887  0.8846     0.979    0.9291  0.8671
#
# ===== Metrics from: metrics_ChemBERTa_10M_MTR_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.986  0.9989     0.9249  0.9249     0.986    0.9249  0.8498
# LightGBM     0.979  0.9968     0.8500  0.9890     0.979    0.9062  0.8274
# CatBoost     0.972  0.9958     0.8182  0.9853     0.972    0.8814  0.7859
#
# ===== Metrics from: metrics_ChemBERTa_5M_MTR_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.979  0.9905     0.9887  0.8846     0.979    0.9291  0.8671
# LightGBM     0.972  0.9740     0.9432  0.8808     0.972    0.9090  0.8216
# CatBoost     0.979  0.9888     0.9887  0.8846     0.979    0.9291  0.8671
#
# ===== Metrics from: metrics_ChemBERTa_5M_MTR_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.979  0.9958     0.8500  0.9890     0.979    0.9062  0.8274
# LightGBM     0.972  1.0000     0.8182  0.9853     0.972    0.8814  0.7859
# CatBoost     0.979  0.9979     0.8500  0.9890     0.979    0.9062  0.8274
#
# ===== Metrics from: metrics_ChemBERTa_77M_MLM_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.986  0.9852     0.9924  0.9231     0.986    0.9545  0.9129
# LightGBM     0.986  0.9669     0.9924  0.9231     0.986    0.9545  0.9129
# CatBoost     0.986  0.9870     0.9924  0.9231     0.986    0.9545  0.9129
#
# ===== Metrics from: metrics_ChemBERTa_77M_MLM_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.979  0.9947     0.8500  0.9890     0.979    0.9062  0.8274
# LightGBM     0.972  0.9989     0.8182  0.9853     0.972    0.8814  0.7859
# CatBoost     0.972  0.9947     0.8182  0.9853     0.972    0.8814  0.7859
#
# ===== Metrics from: metrics_ChemBERTa_77M_MTR_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.979  0.9479     0.9887  0.8846     0.979    0.9291  0.8671
# LightGBM     0.979  0.9503     0.9887  0.8846     0.979    0.9291  0.8671
# CatBoost     0.972  0.9385     0.9432  0.8808     0.972    0.9090  0.8216
#
# ===== Metrics from: metrics_ChemBERTa_77M_MTR_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.986  0.9979     0.9249  0.9249     0.986    0.9249  0.8498
# LightGBM     0.972  0.9958     0.8296  0.9175     0.972    0.8676  0.7420
# CatBoost     0.965  0.9863     0.7962  0.9139     0.965    0.8436  0.7003
#
# ===== Metrics from: metrics_ChemBERTa_Base_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.958  0.9893     0.9779  0.7692     0.958    0.8387  0.7174
# LightGBM     0.965  0.9686     0.9350  0.8423     0.965    0.8818  0.7717
# CatBoost     0.972  0.9905     0.9432  0.8808     0.972    0.9090  0.8216
#
# ===== Metrics from: metrics_ChemBERTa_Base_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.972  0.9874     0.8296  0.9175     0.972    0.8676  0.7420
# LightGBM     0.993  0.9968     0.9375  0.9963     0.993    0.9648  0.9320
# CatBoost     0.979  0.9968     0.8500  0.9890     0.979    0.9062  0.8274
#
# ===== Metrics from: metrics_MolFormer_Base_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.958  0.9550     0.9779  0.7692     0.958    0.8387  0.7174
# LightGBM     0.965  0.9592     0.9815  0.8077     0.965    0.8715  0.7698
# CatBoost     0.965  0.9763     0.9815  0.8077     0.965    0.8715  0.7698
#
# ===== Metrics from: metrics_MolFormer_Base_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.986  0.9979     0.9249  0.9249     0.986    0.9249  0.8498
# LightGBM     0.993  0.9958     0.9964  0.9286     0.993    0.9597  0.9224
# CatBoost     0.986  0.9979     0.9249  0.9249     0.986    0.9249  0.8498
#
# ===== Metrics from: metrics_MolFormer_Finetuned_embeddings_CT_TOX.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.979  0.9893     0.9887  0.8846     0.979    0.9291  0.8671
# LightGBM     0.979  0.9811     0.9887  0.8846     0.979    0.9291  0.8671
# CatBoost     0.986  0.9917     0.9924  0.9231     0.986    0.9545  0.9129
#
# ===== Metrics from: metrics_MolFormer_Finetuned_embeddings_FDA_APPROVED.npy =====
#           Accuracy     AUC  Precision  Recall  F1 Micro  F1 Macro     MCC
# XGBoost      0.972  0.9926     0.8296  0.9175     0.972    0.8676  0.7420
# LightGBM     0.979  0.9958     0.8713  0.9212     0.979    0.8945  0.7909
# CatBoost     0.972  0.9968     0.8182  0.9853     0.972    0.8814  0.7859
